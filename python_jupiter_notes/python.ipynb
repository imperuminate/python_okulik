# %% [markdown]
# - Типы данных
#     - Базовые
#         - int
#         - float
#         - str
#         - bool
#         - None
#     - Сложные
#         - List []
#         - Tuple () неизменяемые
#         - Set {} уникальные значения(в одном экземпляре), без четкой последовательности, изменяемый
#         - Dictonary {} {неизменяемый тип: любой тип}
# - Канкатенация
# - Операторы:
#     - Арифметические
#     - Сравнения
#     - Присваивания
#     - Логические
#     - Битовые
#     - Принадлежности
#     - Идентичности
# - Способы ввода данных:
#     - Клавиатура
#     - Чтение из файла
#     - База данных
#     - Аpi
# - Способы формирования вывода текста
#     - через +
#     - через ,
#     - через f
# - Преобразование типов данных из одного в другой.
#     - bool - str/int
#     - str - bool       ('')False
#     - int - str/bool   (0)False
#     - list - set
# - Работа с масивами
#     - Распаковка колекций с известным количеством элементов
#     - Срез
# - Работа со строкой
#     - Методы коллекций для строки
#     - Преобразование строки в коллекцию и обратно
#     - Форматирование строки (соединение)
#         - f string
#         - string %
# - Conditions
#     -if elif else
# - Loops
#     - for in
#     - while
# - Functions
#     - with return or without
#     - with arguments and parametrs or without
#     - with positioned or named arguments
#     - with default argument value
#     - unlimited amount of positioned (*args)
#     - unlimited amount of named {**kwargs}
# - Generator function
# - Modules
# - Map
# - lambda
# - ternary operator
# - Filter
# - Datetime https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes
#     - strptime
#     - strftime
# - Decorators
# - List comprehension
# - Class
# - OOP
